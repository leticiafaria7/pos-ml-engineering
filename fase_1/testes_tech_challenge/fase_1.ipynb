# %% [markdown]
# ## Imports

# %%
import requests
import warnings
warnings.filterwarnings('ignore')

url = 'https://books-catalog-api.onrender.com/'

# %% [markdown]
# ## 1. Registro e login de usuário

# %%
# alterar as chaves para os username e password desejados
username = 'teste_video'
password = 'louvre'

payload = {'username':username, 'password':password}

resp = requests.post(f"{url}/api/v1/auth/register", json = payload)
print(resp.json())
# Out:
# {'error': 'Nome de usuário já está em uso'}

# %%
# colocar username e senha registrados
payload = {'username':username, 'password':password}
resp = requests.post(f"{url}/api/v1/auth/login", json = payload)

# armazenar o token de acesso na variável access_token
access_token = resp.json()['access_token'] 
print(access_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..r7NbaFLttH4HLw-KSCtx-zIsLsufnpZXx2_LJFxycgo

# %% [markdown]
# ## 2. Informações dos livros

# %% [markdown]
# ### Lista de livros

# %%
header = {'Authorization': f"Bearer {access_token}"}
endpoint_livros = f"{url}/api/v1/books"

# armazenar a lista de livros na variável lista_livros
lista_livros = requests.get(endpoint_livros, headers = header).json()

# %%
lista_livros
# Out:
# {'1': "It's Only the Himalayas",
#  '2': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#  '3': 'See America: A Celebration of Our National Parks & Treasured Sites',
#  '4': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#  '5': 'Under the Tuscan Sun',
#  '6': 'A Summer In Europe',
#  '7': 'The Great Railway Bazaar',
#  '8': 'A Year in Provence (Provence #1)',
#  '9': 'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#  '10': 'Neither Here nor There: Travels in Europe',
#  '11': '1,000 Places to See Before You Die',
#  '12': 'Sharp Objects',
#  '13': 'In a Dark, Dark Wood',
#  '14': 'The Past Never Ends',
#  '15': 'A Murder in Time',
#  '16': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#  '17': 'The Last Mile (Amos Decker #2)',
#  '18': 'That Darkness (Gardiner and Renner #1)',
#  '19': 'Tastes Like Fear (DI Marnie Rome #3)',
#  '20': 'A Time of Torment (Charlie Parker #14)',
#  '21': 'A Study in Scarlet (Sherlock Holmes #1)',
#  '22': 'Poisonous (Max Revere Novels #3)',
#  '23': 'Murder at the 42nd Street Library (Raymond Ambler #1)',
#  '24': 'Most Wanted',
#  '25': 'Hide Away (Eve Duncan #20)',
#  '26': 'Boar Island (Anna Pigeon #19)',
#  '27': 'The Widow',
#  '28': 'Playing with Fire',
#  '29': 'What Happened on Beale Street (Secrets of the South Mysteries #2)',
#  '30': "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)",
#  '31': 'Delivering the Truth (Quaker Midwife Mystery #1)',
#  '32': 'The Mysterious Affair at Styles (Hercule Poirot #1)',
#  '33': 'In the Woods (Dublin Murder Squad #1)',
#  '34': 'The Silkworm (Cormoran Strike #2)',
#  '35': 'The Exiled',
#  '36': "The Cuckoo's Calling (Cormoran Strike #1)",
#  '37': 'Extreme Prey (Lucas Davenport #26)',
#  '38': 'Career of Evil (Cormoran Strike #3)',
#  '39': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)",
#  '40': 'The Girl You Lost',
#  '41': 'The Girl In The Ice (DCI Erika Foster #1)',
#  '42': 'Blood Defense (Samantha Brinkman #1)',
#  '43': "1st to Die (Women's Murder Club #1)",
#  '44': 'Tipping the Velvet',
#  '45': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#  '46': 'A Flight of Arrows (The Pathfinders #2)',
#  '47': 'The House by the Lake',
#  '48': 'Mrs. Houdini',
#  '49': 'The Marriage of Opposites',
#  '50': 'Glory over Everything: Beyond The Kitchen House',
#  '51': 'Love, Lies and Spies',
#  '52': 'A Paris Apartment',
#  '53': 'Lilac Girls',
#  '54': 'The Constant Princess (The Tudor Court #1)',
#  '55': 'The Invention of Wings',
#  '56': 'World Without End (The Pillars of the Earth #2)',
#  '57': 'The Passion of Dolssa',
#  '58': 'Girl With a Pearl Earring',
#  '59': 'Voyager (Outlander #3)',
#  '60': 'The Red Tent',
#  '61': 'The Last Painting of Sara de Vos',
#  '62': 'The Guernsey Literary and Potato Peel Pie Society',
#  '63': 'Girl in the Blue Coat',
#  '64': 'Between Shades of Gray',
#  '65': 'While You Were Mine',
#  '66': 'The Secret Healer',
#  '67': 'Starlark',
#  '68': 'Lost Among the Living',
#  '69': "A Spy's Devotion (The Regency Spies of London #1)",
#  '70': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  '71': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#  '72': 'This One Summer',
#  '73': 'The Nameless City (The Nameless City #1)',
#  '74': 'Saga, Volume 5 (Saga (Collected Editions) #5)',
#  '75': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#  '76': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#  '77': 'Pop Gun War, Volume 1: Gift',
#  '78': 'Patience',
#  '79': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#  '80': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#  '81': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#  '82': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#  '83': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#  '84': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#  '85': 'I am a Hero Omnibus Volume 1',
#  '86': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#  '87': 'Danganronpa Volume 1',
#  '88': 'Codename Baboushka, Volume 1: The Conclave of Death',
#  '89': 'Camp Midnight',
#  '90': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#  '91': 'The Shadow Hero (The Shadow Hero)',
#  '92': 'Fables, Vol. 1: Legends in Exile (Fables #1)',
#  '93': 'Batman: The Long Halloween (Batman)',
#  '94': 'Batman: The Dark Knight Returns (Batman)',
#  '95': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#  '96': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#  '97': 'Through the Woods',
#  '98': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#  '99': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)',
#  '100': 'Robin War',
#  '101': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)',
#  '102': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)',
#  '103': 'Lowriders to the Center of the Earth (Lowriders in Space #2)',
#  '104': 'El Deafo',
#  '105': 'Batman: Europa',
#  '106': 'Art Ops Vol. 1',
#  '107': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#  '108': 'Fruits Basket, Vol. 9 (Fruits Basket #9)',
#  '109': 'Roller Girl',
#  '110': 'Fruits Basket, Vol. 7 (Fruits Basket #7)',
#  '111': 'Fruits Basket, Vol. 6 (Fruits Basket #6)',
#  '112': 'Death Note, Vol. 6: Give-and-Take (Death Note #6)',
#  '113': 'Fruits Basket, Vol. 5 (Fruits Basket #5)',
#  '114': 'Death Note, Vol. 5: Whiteout (Death Note #5)',
#  '115': 'The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of Momochi House #4)',
#  '116': 'Fruits Basket, Vol. 4 (Fruits Basket #4)',
#  '117': 'The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + The Divine)',
#  '118': 'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)',
#  '119': 'Saga, Volume 3 (Saga (Collected Editions) #3)',
#  '120': 'Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)',
#  '121': 'Persepolis: The Story of a Childhood (Persepolis #1-2)',
#  '122': 'Original Fake',
#  '123': 'Grayson, Vol 3: Nemesis (Grayson #3)',
#  '124': 'Fruits Basket, Vol. 3 (Fruits Basket #3)',
#  '125': 'Black Butler, Vol. 1 (Black Butler #1)',
#  '126': 'Awkward',
#  '127': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)",
#  '128': 'Saga, Volume 2 (Saga (Collected Editions) #2)',
#  '129': 'Fruits Basket, Vol. 2 (Fruits Basket #2)',
#  '130': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)',
#  '131': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)',
#  '132': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)',
#  '133': 'The Complete Maus (Maus #1-2)',
#  '134': 'Skip Beat!, Vol. 01 (Skip Beat! #1)',
#  '135': 'Saga, Volume 1 (Saga (Collected Editions) #1)',
#  '136': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)',
#  '137': 'Paper Girls, Vol. 1 (Paper Girls #1-5)',
#  '138': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)',
#  '139': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)',
#  '140': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)',
#  '141': 'Giant Days, Vol. 1 (Giant Days #1-4)',
#  '142': 'Fruits Basket, Vol. 1 (Fruits Basket #1)',
#  '143': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)',
#  '144': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)',
#  '145': 'The Secret Garden',
#  '146': 'The Metamorphosis',
#  '147': "The Pilgrim's Progress",
#  '148': 'The Hound of the Baskervilles (Sherlock Holmes #5)',
#  '149': 'Little Women (Little Women #1)',
#  '150': 'Gone with the Wind',
#  '151': 'Candide',
#  '152': 'Animal Farm',
#  '153': 'Wuthering Heights',
#  '154': 'The Picture of Dorian Gray',
#  '155': 'The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])',
#  '156': 'Beowulf',
#  '157': 'And Then There Were None',
#  '158': 'The Story of Hong Gildong',
#  '159': 'The Little Prince',
#  '160': 'Sense and Sensibility',
#  '161': 'Of Mice and Men',
#  '162': 'Emma',
#  '163': "Alice in Wonderland (Alice's Adventures in Wonderland #1)",
#  '164': "Sophie's World",
#  '165': 'The Death of Humanity: and the Case for Life',
#  '166': 'The Stranger',
#  '167': 'Proofs of God: Classical Arguments from Tertullian to Barth',
#  '168': 'Kierkegaard: A Christian Missionary to Christians',
#  '169': 'At The Existentialist Café: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others',
#  '170': 'Critique of Pure Reason',
#  '171': 'Run, Spot, Run: The Ethics of Keeping Pets',
#  '172': 'The Nicomachean Ethics',
#  '173': 'Meditations',
#  '174': 'Beyond Good and Evil',
#  '175': 'Chase Me (Paris Nights #2)',
#  '176': 'Black Dust',
#  '177': 'Her Backup Boyfriend (The Sorensen Family #1)',
#  '178': 'First and First (Five Boroughs #3)',
#  '179': 'Fifty Shades Darker (Fifty Shades #2)',
#  '180': 'The Wedding Dress',
#  '181': 'Suddenly in Love (Lake Haven #1)',
#  '182': 'Something More Than This',
#  '183': 'Doing It Over (Most Likely To #1)',
#  '184': "The Wedding Pact (The O'Malleys #2)",
#  '185': 'Hold Your Breath (Search and Rescue #1)',
#  '186': 'Dirty (Dive Bar #1)',
#  '187': 'Take Me Home Tonight (Rock Star Romance #3)',
#  '188': 'Off the Hook (Fishing for Trouble #1)',
#  '189': "A Gentleman's Position (Society of Gentlemen #3)",
#  '190': 'Sit, Stay, Love',
#  '191': "A Girl's Guide to Moving On (New Beginnings #2)",
#  '192': 'The Perfect Play (Play by Play #1)',
#  '193': 'Dark Lover (Black Dagger Brotherhood #1)',
#  '194': 'Changing the Game (Play by Play #2)',
#  '195': 'A Walk to Remember',
#  '196': 'The Purest Hook (Second Circle Tattoos #3)',
#  '197': 'The Obsession',
#  '198': 'Reservations for Two',
#  '199': "Best of My Love (Fool's Gold #20)",
#  '200': 'Where Lightning Strikes (Bleeding Stars #3)',
#  '201': 'This One Moment (Pushing Limits #1)',
#  '202': 'Rhythm, Chord & Malykhin',
#  '203': 'My Perfect Mistake (Over the Top #1)',
#  '204': 'Listen to Me (Fusion #1)',
#  '205': 'Imperfect Harmony',
#  '206': 'Fighting Fate (Fighting #6)',
#  '207': 'Deep Under (Walker Security #1)',
#  '208': "Charity's Cross (Charles Towne Belles #4)",
#  '209': 'Bounty (Colorado Mountain #7)',
#  '210': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#  '211': "Will You Won't You Want Me?",
#  '212': 'Keep Me Posted',
#  '213': 'Grey (Fifty Shades #4)',
#  '214': 'Meternity',
#  '215': 'Some Women',
#  '216': 'Shopaholic Ties the Knot (Shopaholic #3)',
#  '217': 'Can You Keep a Secret?',
#  '218': 'Twenties Girl',
#  '219': 'The Undomestic Goddess',
#  '220': 'The Nanny Diaries (Nanny #1)',
#  '221': 'The Devil Wears Prada (The Devil Wears Prada #1)',
#  '222': 'Something Borrowed (Darcy & Rachel #1)',
#  '223': 'Something Blue (Darcy & Rachel #2)',
#  '224': "I've Got Your Number",
#  '225': 'The Edge of Reason (Bridget Jones #2)',
#  '226': "Bridget Jones's Diary (Bridget Jones #1)",
#  '227': 'Soumission',
#  '228': 'Private Paris (Private #10)',
#  '229': 'We Love You, Charlie Freeman',
#  '230': 'Thirst',
#  '231': 'The Murder That Never Was (Forensic Instincts #5)',
#  '232': 'Tuesday Nights in 1980',
#  '233': 'The Vacationers',
#  '234': 'The Regional Office Is Under Attack!',
#  '235': 'Finders Keepers (Bill Hodges Trilogy #2)',
#  '236': 'The Time Keeper',
#  '237': 'The Testament of Mary',
#  '238': 'The First Hostage (J.B. Collins #2)',
#  '239': 'Take Me with You',
#  '240': 'Still Life with Bread Crumbs',
#  '241': 'Shtum',
#  '242': 'My Name Is Lucy Barton',
#  '243': 'My Mrs. Brown',
#  '244': 'Mr. Mercedes (Bill Hodges Trilogy #1)',
#  '245': 'I Am Pilgrim (Pilgrim #1)',
#  '246': 'Eligible (The Austen Project #4)',
#  '247': 'Eight Hundred Grapes',
#  '248': 'Dear Mr. Knightley',
#  '249': 'Cometh the Hour (The Clifton Chronicles #6)',
#  '250': 'Balloon Animals',
#  '251': 'A Man Called Ove',
#  '252': 'The Silent Sister (Riley MacPherson #1)',
#  '253': 'The Dinner Party',
#  '254': 'The Improbability of Love',
#  '255': 'Mothering Sunday',
#  '256': 'Lies and Other Acts of Love',
#  '257': 'Daredevils',
#  '258': '11/22/63',
#  '259': 'The Shack',
#  '260': 'The High Mountains of Portugal',
#  '261': "Miller's Valley",
#  '262': 'Hystopia: A Novel',
#  '263': 'The Bourne Identity (Jason Bourne #1)',
#  '264': 'Sister Dear',
#  '265': 'Memoirs of a Geisha',
#  '266': 'Me Before You (Me Before You #1)',
#  '267': 'Deception Point',
#  '268': 'The Little Paris Bookshop',
#  '269': 'The Firm',
#  '270': 'The Expatriates',
#  '271': 'Siddhartha',
#  '272': 'Last One Home (New Beginnings #1)',
#  '273': 'Digital Fortress',
#  '274': 'Atlas Shrugged',
#  '275': 'Three-Martini Lunch',
#  '276': 'The Nightingale',
#  '277': 'The Infinities',
#  '278': "The Husband's Secret",
#  '279': 'The Da Vinci Code (Robert Langdon #2)',
#  '280': 'The Art of Fielding',
#  '281': 'Lila (Gilead #3)',
#  '282': 'Jurassic Park (Jurassic Park #1)',
#  '283': 'Inferno (Robert Langdon #4)',
#  '284': 'Crazy Rich Asians (Crazy Rich Asians #1)',
#  '285': 'Big Little Lies',
#  '286': 'The Course of Love',
#  '287': "When I'm Gone",
#  '288': 'The Silent Wife',
#  '289': 'The Bette Davis Club',
#  '290': 'Kitchens of the Great Midwest',
#  '291': 'Bright Lines',
#  '292': 'Birdsong: A Story in Pictures',
#  '293': 'The Bear and the Piano',
#  '294': 'The Secret of Dreadwillow Carse',
#  '295': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#  '296': 'Little Red',
#  '297': "Walt Disney's Alice in Wonderland",
#  '298': 'Twenty Yawns',
#  '299': 'Rain Fish',
#  '300': 'Once Was a Time',
#  '301': 'Luis Paints the World',
#  '302': 'Nap-a-Roo',
#  '303': 'The Whale',
#  '304': 'Shrunken Treasures: Literary Classics, Short, Sweet, and Silly',
#  '305': 'Raymie Nightingale',
#  '306': 'Playing from the Heart',
#  '307': 'Maybe Something Beautiful: How Art Transformed a Neighborhood',
#  '308': 'The Wild Robot',
#  '309': 'The Thing About Jellyfish',
#  '310': 'The Lonely Ones',
#  '311': 'The Day the Crayons Came Home (Crayons)',
#  '312': 'The Cat in the Hat (Beginner Books B-1)',
#  '313': 'Red: The True Story of Red Riding Hood',
#  '314': 'Horrible Bear!',
#  '315': 'Green Eggs and Ham (Beginner Books B-16)',
#  '316': 'Counting Thyme',
#  '317': 'Are We There Yet?',
#  '318': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)',
#  '319': 'Matilda',
#  '320': 'Charlie and the Chocolate Factory (Charlie Bucket #1)',
#  '321': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#  '322': 'You Are What You Love: The Spiritual Power of Habit',
#  '323': 'God: The Most Unpleasant Character in All Fiction',
#  '324': 'The Book of Mormon',
#  '325': 'A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam',
#  '326': 'The Bhagavad Gita',
#  '327': "Choosing Our Religion: The Spiritual Lives of America's Nones",
#  '328': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#  '329': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#  '330': 'Reasons to Stay Alive',
#  '331': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#  '332': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#  '333': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#  '334': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#  '335': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#  '336': 'The Electric Pencil: Drawings from Inside State Hospital No. 3',
#  '337': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#  '338': 'Reskilling America: Learning to Labor in the Twenty-First Century',
#  '339': 'In the Country We Love: My Family Divided',
#  '340': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#  '341': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#  '342': 'Algorithms to Live By: The Computer Science of Human Decisions',
#  '343': 'The Power of Now: A Guide to Spiritual Enlightenment',
#  '344': "The Omnivore's Dilemma: A Natural History of Four Meals",
#  '345': 'The Genius of Birds',
#  '346': "The Artist's Way: A Spiritual Path to Higher Creativity",
#  '347': "So You've Been Publicly Shamed",
#  '348': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#  '349': 'Big Magic: Creative Living Beyond Fear',
#  '350': 'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#  '351': 'Agnostic: A Spirited Manifesto',
#  '352': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#  '353': "What's It Like in Space?: Stories from Astronauts Who've Been There",
#  '354': 'The Year of Magical Thinking',
#  '355': 'The Literature Book (Big Ideas Simply Explained)',
#  '356': 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World’s Most Precious Manuscripts',
#  '357': 'Swell: A Year of Waves',
#  '358': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon',
#  '359': 'Looking for Lovely: Collecting the Moments that Matter',
#  '360': 'Let It Out: A Journey Through Journaling',
#  '361': 'Hamilton: The Revolution',
#  '362': 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years',
#  '363': 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life',
#  '364': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#  '365': 'Brain on Fire: My Month of Madness',
#  '366': 'Abstract City',
#  '367': '13 Hours: The Inside Account of What Really Happened In Benghazi',
#  '368': 'The Lonely City: Adventures in the Art of Being Alone',
#  '369': 'The Diary of a Young Girl',
#  '370': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#  '371': 'Furiously Happy: A Funny Book About Horrible Things',
#  '372': 'The Sleep Revolution: Transforming Your Life, One Night at a Time',
#  '373': 'Mother, Can You Not?',
#  '374': "A Mother's Reckoning: Living in the Aftermath of Tragedy",
#  '375': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works',
#  '376': "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster",
#  '377': 'Zero to One: Notes on Startups, or How to Build the Future',
#  '378': 'Why Not Me?',
#  '379': 'When Breath Becomes Air',
#  '380': "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer",
#  '381': 'Smarter Faster Better: The Secrets of Being Productive in Life and Business',
#  '382': 'Rising Strong',
#  '383': "Man's Search for Meaning",
#  '384': "Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations",
#  '385': 'Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want',
#  '386': 'I Will Find You',
#  '387': "Brazen: The Courage to Find the You That's Been Hiding",
#  '388': 'Between the World and Me',
#  '389': 'Being Mortal: Medicine and What Matters in the End',
#  '390': 'A Murder Over a Girl: Justice, Gender, Junior High',
#  '391': 'For the Love: Fighting for Grace in a World of Impossible Standards',
#  '392': 'Finding God in the Ruins: How God Redeems Pain',
#  '393': 'The Man Who Mistook His Wife for a Hat and Other Clinical Tales',
#  '394': 'In Cold Blood',
#  '395': 'Girl, Interrupted',
#  '396': 'Why Save the Bankers?: And Other Essays on Our Economic and Political Crisis',
#  '397': "Talking to Girls About Duran Duran: One Young Man's Quest for True Love and a Cooler Haircut",
#  '398': 'My Mother Was Nuts',
#  '399': 'Data, A Love Story: How I Gamed Online Dating to Meet My Match',
#  '400': 'The Jazz of Physics: The Secret Link Between Music and the Structure of the Universe',
#  '401': 'The Gunning of America: Business and the Making of American Gun Culture',
#  '402': "The Geography of Bliss: One Grump's Search for the Happiest Places in the World",
#  '403': 'God Is Not Great: How Religion Poisons Everything',
#  '404': "We the People: The Modern-Day Figures Who Have Reshaped and Affirmed the Founding Fathers' Vision of America",
#  '405': 'Very Good Lives: The Fringe Benefits of Failure and the Importance of Imagination',
#  '406': 'Unstuffed: Decluttering Your Home, Mind, and Soul',
#  '407': 'Under the Banner of Heaven: A Story of Violent Faith',
#  '408': "Trespassing Across America: One Man's Epic, Never-Done-Before (and Sort of Illegal) Hike Across the Heartland",
#  '409': 'The Name of God is Mercy',
#  '410': 'Stiff: The Curious Lives of Human Cadavers',
#  '411': 'Spilled Milk: Based on a True Story',
#  '412': 'Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars',
#  '413': 'Outliers: The Story of Success',
#  '414': 'Notes from a Small Island (Notes From a Small Island #1)',
#  '415': 'Night (The Night Trilogy #1)',
#  '416': 'Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing',
#  '417': 'Letter to a Christian Nation',
#  '418': "Let's Pretend This Never Happened: A Mostly True Memoir",
#  '419': "It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond",
#  '420': 'Into the Wild',
#  '421': "In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin",
#  '422': 'I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban',
#  '423': 'Gratitude',
#  '424': 'Disrupted: My Misadventure in the Start-Up Bubble',
#  '425': 'Brave Enough',
#  '426': 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen',
#  '427': 'Blink: The Power of Thinking Without Thinking',
#  '428': 'Black Flags: The Rise of ISIS',
#  '429': 'Are We Smart Enough to Know How Smart Animals Are?',
#  '430': 'A Walk in the Woods: Rediscovering America on the Appalachian Trail',
#  '431': 'The Suffragettes (Little Black Classics, #96)',
#  '432': "Kindle Paperwhite User's Guide",
#  '433': 'H is for Hawk',
#  '434': 'Travels with Charley: In Search of America',
#  '435': 'The Tumor',
#  '436': 'The End of the Jesus Era (An Investigation #1)',
#  '437': 'Eat, Pray, Love',
#  '438': 'Rip it Up and Start Again',
#  '439': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#  '440': 'How Music Works',
#  '441': 'Love Is a Mix Tape (Music #1)',
#  '442': 'Please Kill Me: The Uncensored Oral History of Punk',
#  '443': "Kill 'Em and Leave: Searching for James Brown and the American Soul",
#  '444': 'Chronicles, Vol. 1',
#  '445': 'This Is Your Brain on Music: The Science of a Human Obsession',
#  '446': 'Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#  '447': 'No One Here Gets Out Alive',
#  '448': 'Life',
#  '449': "Old Records Never Die: One Man's Quest for His Vinyl and His Past",
#  '450': 'Forever Rockers (The Rocker #12)',
#  '451': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#  '452': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#  '453': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#  '454': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#  '455': 'Aladdin and His Wonderful Lamp',
#  '456': 'Penny Maybe',
#  '457': 'Maude (1883-1993):She Grew Up with the country',
#  '458': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#  '459': 'Soul Reader',
#  '460': 'Bossypants',
#  '461': 'A World of Flavor: Your Gluten Free Passport',
#  '462': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#  '463': 'Tracing Numbers on a Train',
#  '464': 'Thirteen Reasons Why',
#  '465': 'The Secret (The Secret #1)',
#  '466': 'The Psychopath Test: A Journey Through the Madness Industry',
#  '467': 'The Kite Runner',
#  '468': 'The Girl on the Train',
#  '469': 'The Emerald Mystery',
#  '470': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#  '471': 'The Art of War',
#  '472': 'Secrets and Lace (Fatal Hearts #1)',
#  '473': 'Romero and Juliet: A Tragic Tale of Love and Zombies',
#  '474': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#  '475': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#  '476': 'Large Print Heart of the Pride',
#  '477': 'Grumbles',
#  '478': 'First Steps for New Christians (Print Edition)',
#  '479': 'Eureka Trivia 6.0',
#  '480': 'Drive: The Surprising Truth About What Motivates Us',
#  '481': 'Done Rubbed Out (Reightman & Bailey #1)',
#  '482': 'Beauty Restored (Riley Family Legacy Novellas #3)',
#  '483': "Ayumi's Violin",
#  '484': 'Anonymous',
#  '485': 'Amy Meets the Saints and Sages',
#  '486': 'Amatus',
#  '487': 'V for Vendetta (V for Vendetta Complete)',
#  '488': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#  '489': 'The Wright Brothers',
#  '490': 'The Songs of the Gods',
#  '491': 'The Rosie Project (Don Tillman #1)',
#  '492': 'The Power of Habit: Why We Do What We Do in Life and Business',
#  '493': 'Steve Jobs',
#  '494': 'Luckiest Girl Alive',
#  '495': 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments',
#  '496': 'Lady Midnight (The Dark Artifices #1)',
#  '497': 'Hush, Hush (Hush, Hush #1)',
#  '498': 'Greek Mythic History',
#  '499': 'Every Last Word',
#  '500': 'Daily Fantasy Sports',
#  '501': 'Clockwork Angel (The Infernal Devices #1)',
#  '502': 'City of Fallen Angels (The Mortal Instruments #4)',
#  '503': 'City of Bones (The Mortal Instruments #1)',
#  '504': 'City of Ashes (The Mortal Instruments #2)',
#  '505': 'Carry On, Warrior: Thoughts on Life Unarmed',
#  '506': 'Carrie',
#  '507': 'Angels & Demons (Robert Langdon #1)',
#  '508': 'The Three Searches, Meaning, and the Story',
#  '509': 'Raspberry Pi Electronics Projects for the Evil Genius',
#  '510': 'How to Speak Golf: An Illustrated Guide to Links Lingo',
#  '511': 'Eleanor & Park',
#  '512': 'Troublemaker: Surviving Hollywood and Scientology',
#  '513': 'Adultery',
#  '514': 'Unlimited Intuition Now',
#  '515': 'Underlying Notes',
#  '516': 'The New Brand You: Your New Image Makes the Sale for You',
#  '517': 'The Flowers Lied',
#  '518': 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond',
#  '519': 'Modern Day Fables',
#  '520': 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)',
#  '521': 'The Martian (The Martian #1)',
#  '522': 'Left Behind (Left Behind #1)',
#  '523': 'John Vassos: Industrial Design for Modern Life',
#  '524': "I'll Give You the Sun",
#  '525': "Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back",
#  '526': "Ender's Game (The Ender Quintet #1)",
#  '527': 'Death by Leisure: A Cautionary Tale',
#  '528': 'Wildlife of New York: A Five-Borough Coloring Book',
#  '529': "The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible",
#  '530': 'The Great Gatsby',
#  '531': 'The Good Girl',
#  '532': 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change',
#  '533': 'Steal Like an Artist: 10 Things Nobody Told You About Being Creative',
#  '534': 'Life of Pi',
#  '535': 'The Sound Of Love',
#  '536': 'The Perks of Being a Wallflower',
#  '537': 'The Makings of a Fatherless Child',
#  '538': 'The Hobbit (Middle-Earth Universe)',
#  '539': 'The Fellowship of the Ring (The Lord of the Rings #1)',
#  '540': 'Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman',
#  '541': 'Musicophilia: Tales of Music and the Brain',
#  '542': 'What If?: Serious Scientific Answers to Absurd Hypothetical Questions',
#  '543': 'The Fault in Our Stars',
#  '544': 'The Dream Thieves (The Raven Cycle #2)',
#  '545': 'The 5th Wave (The 5th Wave #1)',
#  '546': 'Shiver (The Wolves of Mercy Falls #1)',
#  '547': 'Remember Me?',
#  '548': 'If I Stay (If I Stay #1)',
#  '549': "I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)",
#  '550': 'Harry Potter and the Deathly Hallows (Harry Potter #7)',
#  '551': 'Fool Me Once',
#  '552': 'Drama',
#  '553': 'Blue Lily, Lily Blue (The Raven Cycle #3)',
#  '554': 'Alight (The Generations Trilogy #2)',
#  '555': 'Vogue Colors A to Z: A Fashion Coloring Book',
#  '556': 'The Shining (The Shining #1)',
#  '557': 'The Hunger Games (The Hunger Games #1)',
#  '558': 'Outlander (Outlander #1)',
#  '559': 'Mockingjay (The Hunger Games #3)',
#  '560': "Harry Potter and the Sorcerer's Stone (Harry Potter #1)",
#  '561': 'Confessions of a Shopaholic (Shopaholic #1)',
#  '562': 'Zero History (Blue Ant #3)',
#  '563': 'World War Z: An Oral History of the Zombie War',
#  '564': 'Wild: From Lost to Found on the Pacific Crest Trail',
#  '565': "Where'd You Go, Bernadette",
#  '566': 'Twilight (Twilight #1)',
#  '567': 'The Paris Wife',
#  '568': 'The Maze Runner (The Maze Runner #1)',
#  '569': "The Lover's Dictionary",
#  '570': 'The Goldfinch',
#  '571': 'The Giver (The Giver Quartet #1)',
#  '572': 'The Girl Who Played with Fire (Millennium Trilogy #2)',
#  '573': 'The Demon-Haunted World: Science as a Candle in the Dark',
#  '574': 'The Book Thief',
#  '575': 'The Autobiography of Malcolm X',
#  '576': 'Shopaholic & Baby (Shopaholic #5)',
#  '577': "Quiet: The Power of Introverts in a World That Can't Stop Talking",
#  '578': 'Packing for Mars: The Curious Science of Life in the Void',
#  '579': 'Orange Is the New Black',
#  '580': 'One for the Money (Stephanie Plum #1)',
#  '581': 'Morning Star (Red Rising #3)',
#  '582': 'Life After Life',
#  '583': 'Lean In: Women, Work, and the Will to Lead',
#  '584': 'Is Everyone Hanging Out Without Me? (And Other Concerns)',
#  '585': 'Gone Girl',
#  '586': 'Fellside',
#  '587': 'Eclipse (Twilight #3)',
#  '588': 'Dracula',
#  '589': 'Dead Wake: The Last Crossing of the Lusitania',
#  '590': 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants',
#  '591': 'Dark Places',
#  '592': 'Breaking Dawn (Twilight #4)',
#  '593': 'Beautiful Creatures (Caster Chronicles #1)',
#  '594': 'A Visit from the Goon Squad',
#  '595': 'The Zombie Room',
#  '596': 'The Name of the Wind (The Kingkiller Chronicle #1)',
#  '597': 'Taking Shots (Assassins #1)',
#  '598': 'Shatter Me (Shatter Me #1)',
#  '599': 'Paradise Lost (Paradise #1)',
#  '600': 'On the Road (Duluoz Legend)',
#  '601': 'Jane Eyre',
#  '602': 'Frankenstein',
#  '603': 'Mesaerion: The Best Science Fiction Stories 1800-1849',
#  '604': 'Join',
#  '605': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#  '606': 'The Project',
#  '607': 'Soft Apocalypse',
#  '608': 'Sleeping Giants (Themis Files #1)',
#  '609': 'Arena',
#  '610': 'Foundation (Foundation (Publication Order) #1)',
#  '611': "The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)",
#  '612': 'Ready Player One',
#  '613': "Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)",
#  '614': 'Dune (Dune #1)',
#  '615': 'Do Androids Dream of Electric Sheep? (Blade Runner #1)',
#  '616': 'Three Wishes (River of Time: California #1)',
#  '617': 'The Last Girl (The Dominion Trilogy #1)',
#  '618': "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)",
#  '619': 'The Book of Basketball: The NBA According to The Sports Guy',
#  '620': 'Friday Night Lights: A Town, a Team, and a Dream',
#  '621': 'Sugar Rush (Offensive Line #2)',
#  '622': 'Settling the Score (The Summer Games #1)',
#  '623': 'Icing (Aces Hockey #2)',
#  '624': 'The Torch Is Passed: A Harding Family Story',
#  '625': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#  '626': 'The Art Forger',
#  '627': 'On a Midnight Clear',
#  '628': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#  '629': 'Shobu Samurai, Project Aryoku (#3)',
#  '630': 'Modern Romance',
#  '631': "The White Queen (The Cousins' War #1)",
#  '632': 'The Song of Achilles',
#  '633': 'The Immortal Life of Henrietta Lacks',
#  '634': 'The Dovekeepers',
#  '635': 'More Than Music (Chasing the Dream #1)',
#  '636': 'Code Name Verity (Code Name Verity #1)',
#  '637': 'Cell',
#  '638': 'Angels Walking (Angels Walking #1)',
#  '639': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#  '640': "A People's History of the United States",
#  '641': 'A Brush of Wings (Angels Walking #3)',
#  '642': 'Rook',
#  '643': 'The Midnight Watch: A Novel of the Titanic and the Californian',
#  '644': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#  '645': 'The Children',
#  '646': 'One with You (Crossfire #5)',
#  '647': 'Without Shame',
#  '648': 'Watchmen',
#  '649': "A Hero's Curse (The Unseen Chronicles #1)",
#  '650': '23 Degrees South: A Tropical Tale of Changing Whether...',
#  '651': 'The Glass Castle',
#  '652': 'The Drowning Girls',
#  '653': 'Team of Rivals: The Political Genius of Abraham Lincoln',
#  '654': 'John Adams',
#  '655': 'Good in Bed (Cannie Shapiro #1)',
#  '656': 'The Joy of Cooking',
#  '657': 'The Golden Compass (His Dark Materials #1)',
#  '658': 'The God Delusion',
#  '659': 'Pride and Prejudice',
#  '660': 'Mere Christianity',
#  '661': 'Fun Home: A Family Tragicomic',
#  '662': 'The Raven King (The Raven Cycle #4)',
#  '663': 'Find Her (Detective D.D. Warren #8)',
#  '664': 'Evicted: Poverty and Profit in the American City',
#  '665': 'A Game of Thrones (A Song of Ice and Fire #1)',
#  '666': 'A Clash of Kings (A Song of Ice and Fire #2)',
#  '667': 'The Tipping Point: How Little Things Can Make a Big Difference',
#  '668': 'The Rest Is Noise: Listening to the Twentieth Century',
#  '669': 'The Purpose Driven Life: What on Earth Am I Here for?',
#  '670': "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)",
#  '671': "The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3)",
#  '672': 'The End of Faith: Religion, Terror, and the Future of Reason',
#  '673': 'The Complete Poems',
#  '674': 'The Catcher in the Rye',
#  '675': 'The Case for Christ (Cases for Christianity)',
#  '676': 'The Blind Side: Evolution of a Game',
#  '677': 'Seven Days in the Art World',
#  '678': "Sarah's Key",
#  '679': 'Rogue Lawyer (Rogue Lawyer #1)',
#  '680': 'Manuscript Found in Accra',
#  '681': 'Fire Bound (Sea Haven/Sisters of the Heart #5)',
#  '682': 'Cosmos',
#  '683': '#GIRLBOSS',
#  '684': 'The Sense of an Ending',
#  '685': 'The Republic',
#  '686': 'The Odyssey',
#  '687': 'The Light of the Fireflies',
#  '688': 'The Iliad',
#  '689': 'The Communist Manifesto',
#  '690': 'Lord of the Flies',
#  '691': 'Unicorn Tracks',
#  '692': 'Saga, Volume 6 (Saga (Collected Editions) #6)',
#  '693': 'Princess Between Worlds (Wide-Awake Princess #5)',
#  '694': 'Masks and Shadows',
#  '695': 'Crown of Midnight (Throne of Glass #2)',
#  '696': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#  '697': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#  '698': 'Throne of Glass (Throne of Glass #1)',
#  '699': 'The Glittering Court (The Glittering Court #1)',
#  '700': 'Hollow City (Miss Peregrine’s Peculiar Children #2)',
#  '701': 'The Star-Touched Queen',
#  '702': 'The Hidden Oracle (The Trials of Apollo #1)',
#  '703': 'The Bane Chronicles (The Bane Chronicles #1-11)',
#  '704': 'Island of Dragons (Unwanteds #7)',
#  '705': 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)',
#  '706': 'City of Glass (The Mortal Instruments #3)',
#  '707': 'Searching for Meaning in Gailana',
#  '708': 'A Shard of Ice (The Black Symphony Saga #1)',
#  '709': "King's Folly (The Kinsman Chronicles #1)",
#  '710': 'Every Heart a Doorway (Every Heart A Doorway #1)',
#  '711': 'A Gathering of Shadows (Shades of Magic #2)',
#  '712': 'The Raven Boys (The Raven Cycle #1)',
#  '713': 'The False Prince (The Ascendance Trilogy #1)',
#  '714': 'Tell the Wind and Fire',
#  '715': 'A Feast for Crows (A Song of Ice and Fire #4)',
#  '716': 'The Demonists (Demonist #1)',
#  '717': 'The Beast (Black Dagger Brotherhood #14)',
#  '718': 'Paper and Fire (The Great Library #2)',
#  '719': 'Harry Potter and the Order of the Phoenix (Harry Potter #5)',
#  '720': 'Harry Potter and the Half-Blood Prince (Harry Potter #6)',
#  '721': 'Harry Potter and the Chamber of Secrets (Harry Potter #2)',
#  '722': 'The Rose & the Dagger (The Wrath and the Dawn #2)',
#  '723': 'Soldier (Talon #3)',
#  '724': 'Midnight Riot (Peter Grant/ Rivers of London - books #1)',
#  '725': 'Heir to the Sky',
#  '726': 'Eragon (The Inheritance Cycle #1)',
#  '727': 'Darkfever (Fever #1)',
#  '728': 'Ash',
#  '729': 'A Storm of Swords (A Song of Ice and Fire #3)',
#  '730': 'Vampire Girl (Vampire Girl #1)',
#  '731': 'The Silent Twin (Detective Jennifer Knight #3)',
#  '732': 'The Mirror & the Maze (The Wrath and the Dawn #1.5)',
#  '733': 'Sister Sable (The Mad Queen #1)',
#  '734': 'Shadow Rites (Jane Yellowrock #10)',
#  '735': 'Origins (Alphas 0.5)',
#  '736': 'One Second (Seven #7)',
#  '737': 'Myriad (Prentor #1)',
#  '738': 'Without Borders (Wanderlove #1)',
#  '739': 'The Mistake (Off-Campus #2)',
#  '740': "The Matchmaker's Playbook (Wingmen Inc. #1)",
#  '741': 'The Hook Up (Game On #1)',
#  '742': 'Shameless',
#  '743': 'Off Sides (Off #1)',
#  '744': 'The Requiem Red',
#  '745': 'Set Me Free',
#  '746': 'The Natural History of Us (The Fine Art of Pretending #2)',
#  '747': 'Obsidian (Lux #1)',
#  '748': 'Burning',
#  '749': 'A Fierce and Subtle Poison',
#  '750': 'Scarlett Epstein Hates It Here',
#  '751': 'Nightingale, Sing',
#  '752': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#  '753': 'Frostbite (Vampire Academy #2)',
#  '754': 'Wild Swans',
#  '755': 'Until Friday Night (The Field Party #1)',
#  '756': 'This Is Where It Ends',
#  '757': 'The Darkest Lie',
#  '758': 'My Kind of Crazy',
#  '759': "Don't Get Caught",
#  '760': 'Catching Jordan (Hundred Oaks)',
#  '761': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#  '762': 'The Epidemic (The Program 0.6)',
#  '763': 'Stars Above (The Lunar Chronicles #4.5)',
#  '764': 'No Love Allowed (Dodge Cove #1)',
#  '765': 'Exit, Pursued by a Bear',
#  '766': 'The Alien Club',
#  '767': "Don't Forget Steven",
#  '768': 'South of Sunshine',
#  '769': 'My Life Next Door (My Life Next Door )',
#  '770': 'Future Shock (Future Shock #1)',
#  '771': 'Nightstruck: A Novel',
#  '772': "Tell the Wolves I'm Home",
#  '773': 'Will Grayson, Will Grayson (Will Grayson, Will Grayson)',
#  '774': 'Where She Went (If I Stay #2)',
#  '775': 'Two Summers',
#  '776': 'The Darkest Corners',
#  '777': 'Tell Me Three Things',
#  '778': 'Lola and the Boy Next Door (Anna and the French Kiss #2)',
#  '779': 'Kill the Boy Band',
#  '780': 'Isla and the Happily Ever After (Anna and the French Kiss #3)',
#  '781': 'An Abundance of Katherines',
#  '782': 'Harry Potter and the Prisoner of Azkaban (Harry Potter #3)',
#  '783': 'Walk the Edge (Thunder Road #2)',
#  '784': 'Two Boys Kissing',
#  '785': 'The New Guy (and Other Senior Year Distractions)',
#  '786': 'The Land of 10,000 Madonnas',
#  '787': 'Scarlet (The Lunar Chronicles #2)',
#  '788': 'Legend (Legend #1)',
#  '789': 'Lady Renegades (Rebel Belle #3)',
#  '790': 'Golden (Heart of Dread #3)',
#  '791': 'Cinder (The Lunar Chronicles #1)',
#  '792': 'Boy Meets Boy',
#  '793': 'Annie on My Mind',
#  '794': 'New Moon (Twilight #2)',
#  '795': 'Girl Online On Tour (Girl Online #2)',
#  '796': 'The Haters',
#  '797': 'The Art of Not Breathing',
#  '798': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#  '799': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#  '800': 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics',
#  '801': 'Tipping Point for Planet Earth: How Close Are We to the Edge?',
#  '802': 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality',
#  '803': 'Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World',
#  '804': 'The Origin of Species',
#  '805': 'The Grand Design',
#  '806': 'Peak: Secrets from the New Science of Expertise',
#  '807': 'The Elegant Universe: Superstrings, Hidden Dimensions, and the Quest for the Ultimate Theory',
#  '808': 'The Disappearing Spoon: And Other True Tales of Madness, Love, and the History of the World from the Periodic Table of the Elements',
#  '809': "Surely You're Joking, Mr. Feynman!: Adventures of a Curious Character",
#  '810': 'Seven Brief Lessons on Physics',
#  '811': 'The Selfish Gene',
#  '812': 'A Light in the Attic',
#  '813': 'The Black Maria',
#  '814': "Shakespeare's Sonnets",
#  '815': 'Olio',
#  '816': "You can't bury them all: Poems",
#  '817': 'Slow States of Collapse: Poems',
#  '818': 'Untitled Collection: Sabbath Poems 2014',
#  '819': 'Poems That Make Grown Women Cry',
#  '820': 'Night Sky with Exit Wounds',
#  '821': 'salt.',
#  '822': 'Quarter Life Poetry: Poems for the Young, Broke and Hangry',
#  '823': 'Out of Print: City Lights Spotlight No. 14',
#  '824': 'Les Fleurs du Mal',
#  '825': 'Howl and Other Poems',
#  '826': 'Leave This Song Behind: Teen Poetry at Its Best',
#  '827': 'The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)',
#  '828': 'The Crossover',
#  '829': 'Booked',
#  '830': 'Twenty Love Poems and a Song of Despair',
#  '831': 'Vampire Knight, Vol. 1 (Vampire Knight #1)',
#  '832': 'Wall and Piece',
#  '833': 'Feathers: Displays of Brilliant Plumage',
#  '834': 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking',
#  '835': 'The New Drawing on the Right Side of the Brain',
#  '836': 'History of Beauty',
#  '837': 'The Story of Art',
#  '838': 'The Art Book',
#  '839': 'Ways of Seeing',
#  '840': 'The Lucifer Effect: Understanding How Good People Turn Evil',
#  '841': 'The Golden Condom: And Other Essays on Love Lost and Found',
#  '842': "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle",
#  '843': 'An Unquiet Mind: A Memoir of Moods and Madness',
#  '844': 'Thinking, Fast and Slow',
#  '845': 'Civilization and Its Discontents',
#  '846': '8 Keys to Mental Health Through Exercise',
#  '847': 'The Argonauts',
#  '848': 'M Train',
#  '849': 'Lab Girl',
#  '850': 'Approval Junkie: Adventures in Caring Too Much',
#  '851': 'Running with Scissors',
#  '852': 'Me Talk Pretty One Day',
#  '853': 'Lust & Wonder',
#  '854': 'Life Without a Recipe',
#  '855': 'A Heartbreaking Work of Staggering Genius',
#  '856': "Catastrophic Happiness: Finding Joy in Childhood's Messy Years",
#  '857': 'Fifty Shades Freed (Fifty Shades #3)',
#  '858': 'The Long Haul (Diary of a Wimpy Kid #9)',
#  '859': 'Old School (Diary of a Wimpy Kid #10)',
#  '860': "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction",
#  '861': 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened',
#  '862': 'Dress Your Family in Corduroy and Denim',
#  '863': "Toddlers Are A**holes: It's Not Your Fault",
#  '864': 'When You Are Engulfed in Flames',
#  '865': 'Naked',
#  '866': "Lamb: The Gospel According to Biff, Christ's Childhood Pal",
#  '867': 'Holidays on Ice',
#  '868': 'Security',
#  '869': 'Follow You Home',
#  '870': 'The Loney',
#  '871': 'Pet Sematary',
#  '872': 'Doctor Sleep (The Shining #2)',
#  '873': 'Psycho: Sanitarium (Psycho #1.5)',
#  '874': 'Can You Keep a Secret? (Fear Street Relaunch #4)',
#  '875': 'Red Dragon (Hannibal Lecter #1)',
#  '876': 'Dracula the Un-Dead',
#  '877': 'Night Shift (Night Shift #1-20)',
#  '878': 'Needful Things',
#  '879': 'Misery',
#  '880': 'It',
#  '881': "'Salem's Lot",
#  '882': 'The Stand',
#  '883': 'The Girl with All the Gifts',
#  '884': 'House of Leaves',
#  '885': 'Sapiens: A Brief History of Humankind',
#  '886': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#  '887': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#  '888': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#  '889': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#  '890': 'Zealot: The Life and Times of Jesus of Nazareth',
#  '891': 'A Distant Mirror: The Calamitous 14th Century',
#  '892': '1491: New Revelations of the Americas Before Columbus',
#  '893': 'Brilliant Beacons: A History of the American Lighthouse',
#  '894': '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire of the Imagination',
#  '895': 'A Short History of Nearly Everything',
#  '896': 'The Rise and Fall of the Third Reich: A History of Nazi Germany',
#  '897': 'Catherine the Great: Portrait of a Woman',
#  '898': "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats",
#  '899': 'The Hiding Place',
#  '900': "America's War for the Greater Middle East: A Military History",
#  '901': 'The Guns of August',
#  '902': 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth',
#  '903': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#  '904': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#  '905': 'My Paris Kitchen: Recipes and Stories',
#  '906': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#  '907': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#  '908': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#  '909': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#  '910': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#  '911': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#  '912': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth',
#  '913': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes",
#  '914': 'Barefoot Contessa Back to Basics',
#  '915': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#  '916': 'My Kitchen Year: 136 Recipes That Saved My Life',
#  '917': 'Everyday Italian: 125 Simple and Delicious Recipes',
#  '918': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#  '919': 'Cravings: Recipes for What You Want to Eat',
#  '920': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York',
#  '921': '32 Yolks',
#  '922': 'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#  '923': 'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food (How to Cook Everything)',
#  '924': 'How to Be a Domestic Goddess: Baking and the Art of Comfort Cooking',
#  '925': 'The Barefoot Contessa Cookbook',
#  '926': 'Better Homes and Gardens New Cook Book',
#  '927': 'The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#  '928': 'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens',
#  '929': 'Vegan Vegetarian Omnivore: Dinner for Everyone at the Table',
#  '930': 'The Smitten Kitchen Cookbook',
#  '931': 'The Art of Simple Food: Notes, Lessons, and Recipes from a Delicious Revolution',
#  '932': 'Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World',
#  '933': 'Redeeming Love',
#  '934': 'Close to You',
#  '935': 'Shadows of the Past (Logan Point #1)',
#  '936': 'Like Never Before (Walker Family #2)',
#  '937': 'Counted With the Stars (Out from Egypt #1)',
#  '938': 'If I Run (If I Run #1)',
#  '939': 'The Dirty Little Secrets of Getting Your Dream Job',
#  '940': 'The Third Wave: An Entrepreneur’s Vision of the Future',
#  '941': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#  '942': 'Shoe Dog: A Memoir by the Creator of NIKE',
#  '943': 'Made to Stick: Why Some Ideas Survive and Others Die',
#  '944': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#  '945': 'The Art of Startup Fundraising',
#  '946': 'Born for This: How to Find the Work You Were Meant to Do',
#  '947': "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It",
#  '948': 'Rich Dad, Poor Dad',
#  '949': "The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses",
#  '950': 'Rework',
#  '951': 'Louisa: The Extraordinary Life of Mrs. Adams',
#  '952': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#  '953': "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist",
#  '954': 'Benjamin Franklin: An American Life',
#  '955': 'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)',
#  '956': 'In Her Wake',
#  '957': 'The Elephant Tree',
#  '958': 'Behind Closed Doors',
#  '959': 'You (You #1)',
#  '960': 'The Guilty (Will Robie #4)',
#  '961': 'The 14th Colony (Cotton Malone #11)',
#  '962': 'Give It Back',
#  '963': 'Killing Floor (Jack Reacher #1)',
#  '964': 'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)',
#  '965': 'Far From True (Promise Falls Trilogy #2)',
#  '966': 'The Travelers',
#  '967': 'When We Collided',
#  '968': 'Someone Like You (The Harrisons #2)',
#  '969': 'We Are All Completely Beside Ourselves',
#  '970': 'The Four Agreements: A Practical Guide to Personal Freedom',
#  '971': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#  '972': 'Chasing Heaven: What Dying Taught Me About Living',
#  '973': "If I Gave You God's Phone Number....: Searching for Spirituality in America",
#  '974': 'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain',
#  '975': "A New Earth: Awakening to Your Life's Purpose",
#  '976': 'Logan Kade (Fallen Crest High #5.5)',
#  '977': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#  '978': 'How to Be Miserable: 40 Strategies You Already Use',
#  '979': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress',
#  '980': 'You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#  '981': 'How to Stop Worrying and Start Living',
#  '982': 'All the Light We Cannot See',
#  '983': 'The Girl You Left Behind (The Girl You Left Behind #1)',
#  '984': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#  '985': 'Crazy Love: Overwhelmed by a Relentless God',
#  '986': 'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality',
#  '987': 'Silence in the Dark (Logan Point #4)',
#  '988': 'The Grownup',
#  '989': 'Suzie Snowflake: One beautiful flake (a self-esteem story)',
#  '990': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#  '991': 'Eat Fat, Get Thin',
#  '992': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!',
#  '993': 'The Art and Science of Low Carbohydrate Living',
#  '994': 'Libertarianism for Beginners',
#  '995': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#  '996': "Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#  '997': 'Amid the Chaos',
#  '998': 'Dark Notes',
#  '999': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City'}

# %% [markdown]
# ### Faixa de preço

# %%
# colocar no dict os termos de busca (nenhum deles é obrigatório)
params = {'min':20, 'max':25}

price_range = f"{url}/api/v1/books/price-range"
resp = requests.get(price_range, params = params).json()
resp
# Out:
# [{'availability': 'In stock',
#   'category': 'Philosophy',
#   'id': 171,
#   'image': 'https://books.toscrape.com/media/cache/91/e6/91e6190dcdd7d6cdeb94a82b60917ec4.jpg',
#   'price': 20.02,
#   'rating': 1,
#   'title': 'Run, Spot, Run: The Ethics of Keeping Pets'},
#  {'availability': 'In stock',
#   'category': 'Music',
#   'id': 447,
#   'image': 'https://books.toscrape.com/media/cache/7a/7e/7a7eb52e7075a5305522948375c1316e.jpg',
#   'price': 20.02,
#   'rating': 5,
#   'title': 'No One Here Gets Out Alive'},
#  {'availability': 'In stock',
#   'category': 'Food and Drink',
#   'id': 917,
#   'image': 'https://books.toscrape.com/media/cache/5a/64/5a6499d41ccaad4c4f7eeaa90e16345a.jpg',
#   'price': 20.1,
#   'rating': 5,
#   'title': 'Everyday Italian: 125 Simple and Delicious Recipes'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 584,
#   'image': 'https://books.toscrape.com/media/cache/6b/94/6b94e98f822a42c03c4ff0b9cfdd6e0c.jpg',
#   'price': 20.11,
#   'rating': 3,
#   'title': 'Is Everyone Hanging Out Without Me? (And Other Concerns)'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 653,
#   'image': 'https://books.toscrape.com/media/cache/56/75/567575381760b5c1ec018d10d350fc5f.jpg',
#   'price': 20.12,
#   'rating': 5,
#   'title': 'Team of Rivals: The Political Genius of Abraham Lincoln'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 523,
#   'image': 'https://books.toscrape.com/media/cache/85/a1/85a19d4c20a4801013e8108a166d10af.jpg',
#   'price': 20.22,
#   'rating': 4,
#   'title': 'John Vassos: Industrial Design for Modern Life'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 472,
#   'image': 'https://books.toscrape.com/media/cache/84/7c/847c06b541e2a3b2228b96d97a5fe7a6.jpg',
#   'price': 20.27,
#   'rating': 1,
#   'title': 'Secrets and Lace (Fatal Hearts #1)'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 637,
#   'image': 'https://books.toscrape.com/media/cache/0b/97/0b97282ed82b771ed328e05386a84adb.jpg',
#   'price': 20.29,
#   'rating': 4,
#   'title': 'Cell'},
#  {'availability': 'In stock',
#   'category': 'Mystery',
#   'id': 42,
#   'image': 'https://books.toscrape.com/media/cache/cb/f6/cbf6d4b61953f29d7eedd2c9e01a9d74.jpg',
#   'price': 20.3,
#   'rating': 3,
#   'title': 'Blood Defense (Samantha Brinkman #1)'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 559,
#   'image': 'https://books.toscrape.com/media/cache/76/b4/76b462eda7a84ccf39a543d63c695ca7.jpg',
#   'price': 20.44,
#   'rating': 4,
#   'title': 'Mockingjay (The Hunger Games #3)'},
#  {'availability': 'In stock',
#   'category': 'Womens Fiction',
#   'id': 212,
#   'image': 'https://books.toscrape.com/media/cache/ae/ac/aeac003461b89c7ef826251d940b2afc.jpg',
#   'price': 20.46,
#   'rating': 4,
#   'title': 'Keep Me Posted'},
#  {'availability': 'In stock',
#   'category': 'Christian Fiction',
#   'id': 933,
#   'image': 'https://books.toscrape.com/media/cache/21/21/2121ba78e26194d92c334fde3850f840.jpg',
#   'price': 20.47,
#   'rating': 5,
#   'title': 'Redeeming Love'},
#  {'availability': 'In stock',
#   'category': 'Food and Drink',
#   'id': 919,
#   'image': 'https://books.toscrape.com/media/cache/ae/5c/ae5ca435fb095e374d2c2aa9f7b6f380.jpg',
#   'price': 20.5,
#   'rating': 3,
#   'title': 'Cravings: Recipes for What You Want to Eat'},
#  {'availability': 'In stock',
#   'category': 'Historical Fiction',
#   'id': 51,
#   'image': 'https://books.toscrape.com/media/cache/7a/22/7a224a6e174af91950e9b124afe54e0e.jpg',
#   'price': 20.55,
#   'rating': 2,
#   'title': 'Love, Lies and Spies'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 458,
#   'image': 'https://books.toscrape.com/media/cache/75/dc/75dce2f5949b407161f37f0af249b018.jpg',
#   'price': 20.59,
#   'rating': 5,
#   'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer'},
#  {'availability': 'In stock',
#   'category': 'Poetry',
#   'id': 814,
#   'image': 'https://books.toscrape.com/media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg',
#   'price': 20.66,
#   'rating': 4,
#   'title': "Shakespeare's Sonnets"},
#  {'availability': 'In stock',
#   'category': 'Philosophy',
#   'id': 170,
#   'image': 'https://books.toscrape.com/media/cache/12/6e/126ef8f6473b81808ebbb9cff155e883.jpg',
#   'price': 20.75,
#   'rating': 1,
#   'title': 'Critique of Pure Reason'},
#  {'availability': 'In stock',
#   'category': 'Historical Fiction',
#   'id': 64,
#   'image': 'https://books.toscrape.com/media/cache/f9/19/f919f64fc0e3642cdc604134bfd93774.jpg',
#   'price': 20.79,
#   'rating': 5,
#   'title': 'Between Shades of Gray'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 513,
#   'image': 'https://books.toscrape.com/media/cache/79/d9/79d99cfa5557be0643ba00bfcd35256b.jpg',
#   'price': 20.88,
#   'rating': 5,
#   'title': 'Adultery'},
#  {'availability': 'In stock',
#   'category': 'Mystery',
#   'id': 31,
#   'image': 'https://books.toscrape.com/media/cache/57/31/5731a5d46c2c1e88977eb5e6d1337a2e.jpg',
#   'price': 20.89,
#   'rating': 4,
#   'title': 'Delivering the Truth (Quaker Midwife Mystery #1)'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 533,
#   'image': 'https://books.toscrape.com/media/cache/5f/17/5f17f0e06d7d67717eff3833d309a233.jpg',
#   'price': 20.9,
#   'rating': 2,
#   'title': 'Steal Like an Artist: 10 Things Nobody Told You About Being Creative'},
#  {'availability': 'In stock',
#   'category': 'Romance',
#   'id': 190,
#   'image': 'https://books.toscrape.com/media/cache/8e/40/8e408552c2e7ee81cd60c03c79f604af.jpg',
#   'price': 20.9,
#   'rating': 3,
#   'title': 'Sit, Stay, Love'},
#  {'availability': 'In stock',
#   'category': 'Spirituality',
#   'id': 973,
#   'image': 'https://books.toscrape.com/media/cache/87/fe/87fe3f7f3f62c1b1b81890578c9cf294.jpg',
#   'price': 20.91,
#   'rating': 1,
#   'title': "If I Gave You God's Phone Number....: Searching for Spirituality in America"},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 568,
#   'image': 'https://books.toscrape.com/media/cache/5e/87/5e87e44785de47c2a03091deaa82330f.jpg',
#   'price': 20.93,
#   'rating': 1,
#   'title': 'The Maze Runner (The Maze Runner #1)'},
#  {'availability': 'In stock',
#   'category': 'Sequential Art',
#   'id': 111,
#   'image': 'https://books.toscrape.com/media/cache/94/1a/941a14dec32f0a949c38a325a715c138.jpg',
#   'price': 20.96,
#   'rating': 4,
#   'title': 'Fruits Basket, Vol. 6 (Fruits Basket #6)'},
#  {'availability': 'In stock',
#   'category': 'Business',
#   'id': 945,
#   'image': 'https://books.toscrape.com/media/cache/b3/7b/b37be83183f1dcb759d92bda8f8998a4.jpg',
#   'price': 21.0,
#   'rating': 3,
#   'title': 'The Art of Startup Fundraising'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 232,
#   'image': 'https://books.toscrape.com/media/cache/6b/da/6bdae061cb92c32b0b83cda8dd10275d.jpg',
#   'price': 21.04,
#   'rating': 2,
#   'title': 'Tuesday Nights in 1980'},
#  {'availability': 'In stock',
#   'category': 'Historical Fiction',
#   'id': 59,
#   'image': 'https://books.toscrape.com/media/cache/b5/d8/b5d813da01f2ccd7bcfe34e2b875e752.jpg',
#   'price': 21.07,
#   'rating': 5,
#   'title': 'Voyager (Outlander #3)'},
#  {'availability': 'In stock',
#   'category': 'Young Adult',
#   'id': 792,
#   'image': 'https://books.toscrape.com/media/cache/0b/ac/0baceb72d202880d1441a32193df6e11.jpg',
#   'price': 21.12,
#   'rating': 3,
#   'title': 'Boy Meets Boy'},
#  {'availability': 'In stock',
#   'category': 'Psychology',
#   'id': 844,
#   'image': 'https://books.toscrape.com/media/cache/b4/a5/b4a56663d56f1e84ee1b15bd819563cc.jpg',
#   'price': 21.14,
#   'rating': 1,
#   'title': 'Thinking, Fast and Slow'},
#  {'availability': 'In stock',
#   'category': 'Biography',
#   'id': 952,
#   'image': 'https://books.toscrape.com/media/cache/8b/c4/8bc43a6b42d0283ab4bf611f1b497126.jpg',
#   'price': 21.15,
#   'rating': 2,
#   'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 370,
#   'image': 'https://books.toscrape.com/media/cache/2a/f3/2af39796852729270fb23e05a662a42c.jpg',
#   'price': 21.21,
#   'rating': 3,
#   'title': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 681,
#   'image': 'https://books.toscrape.com/media/cache/cd/53/cd53431a069ee01572988de29ef68da5.jpg',
#   'price': 21.28,
#   'rating': 4,
#   'title': 'Fire Bound (Sea Haven/Sisters of the Heart #5)'},
#  {'availability': 'In stock',
#   'category': 'Psychology',
#   'id': 843,
#   'image': 'https://books.toscrape.com/media/cache/00/29/002924b764dc367dcaa3486fa4c0aa0b.jpg',
#   'price': 21.3,
#   'rating': 3,
#   'title': 'An Unquiet Mind: A Memoir of Moods and Madness'},
#  {'availability': 'In stock',
#   'category': 'Horror',
#   'id': 869,
#   'image': 'https://books.toscrape.com/media/cache/a7/4b/a74b35375ce874153fd352e33bc7bac9.jpg',
#   'price': 21.36,
#   'rating': 1,
#   'title': 'Follow You Home'},
#  {'availability': 'In stock',
#   'category': 'Science Fiction',
#   'id': 609,
#   'image': 'https://books.toscrape.com/media/cache/51/88/518810d182843244a404f2a2a614a93b.jpg',
#   'price': 21.36,
#   'rating': 4,
#   'title': 'Arena'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 593,
#   'image': 'https://books.toscrape.com/media/cache/82/06/8206f351bd1ff6f52eed515a3b366916.jpg',
#   'price': 21.55,
#   'rating': 5,
#   'title': 'Beautiful Creatures (Caster Chronicles #1)'},
#  {'availability': 'In stock',
#   'category': 'Sequential Art',
#   'id': 119,
#   'image': 'https://books.toscrape.com/media/cache/d8/fd/d8fd30b3e5781e880a3efe4c9495b417.jpg',
#   'price': 21.57,
#   'rating': 5,
#   'title': 'Saga, Volume 3 (Saga (Collected Editions) #3)'},
#  {'availability': 'In stock',
#   'category': 'Business',
#   'id': 946,
#   'image': 'https://books.toscrape.com/media/cache/aa/67/aa677a97ecdcbbde7471f1c90ed0cf6f.jpg',
#   'price': 21.59,
#   'rating': 5,
#   'title': 'Born for This: How to Find the Work You Were Meant to Do'},
#  {'availability': 'In stock',
#   'category': 'Sequential Art',
#   'id': 137,
#   'image': 'https://books.toscrape.com/media/cache/87/2b/872ba3b06a97e6662770bc2152595b84.jpg',
#   'price': 21.71,
#   'rating': 4,
#   'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)'},
#  {'availability': 'In stock',
#   'category': 'Fantasy',
#   'id': 734,
#   'image': 'https://books.toscrape.com/media/cache/7a/0d/7a0d52ec06a57c117c0b99c7980756e7.jpg',
#   'price': 21.72,
#   'rating': 4,
#   'title': 'Shadow Rites (Jane Yellowrock #10)'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 427,
#   'image': 'https://books.toscrape.com/media/cache/5d/41/5d415bc31b1f856a2a9dc8706fd19abd.jpg',
#   'price': 21.74,
#   'rating': 5,
#   'title': 'Blink: The Power of Thinking Without Thinking'},
#  {'availability': 'In stock',
#   'category': 'History',
#   'id': 892,
#   'image': 'https://books.toscrape.com/media/cache/88/75/8875f384ce9103281b7f6e86a2b8204d.jpg',
#   'price': 21.8,
#   'rating': 3,
#   'title': '1491: New Revelations of the Americas Before Columbus'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 563,
#   'image': 'https://books.toscrape.com/media/cache/7e/bf/7ebfa1c62b21beeaad37a6474a39cfe8.jpg',
#   'price': 21.8,
#   'rating': 1,
#   'title': 'World War Z: An Oral History of the Zombie War'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 382,
#   'image': 'https://books.toscrape.com/media/cache/3b/f3/3bf3c719382c03984ab9766803bed964.jpg',
#   'price': 21.82,
#   'rating': 3,
#   'title': 'Rising Strong'},
#  {'availability': 'In stock',
#   'category': 'Religion',
#   'id': 322,
#   'image': 'https://books.toscrape.com/media/cache/6b/70/6b70f2cdb17d9ab7551240a88b9211fe.jpg',
#   'price': 21.87,
#   'rating': 4,
#   'title': 'You Are What You Love: The Spiritual Power of Habit'},
#  {'availability': 'In stock',
#   'category': 'Womens Fiction',
#   'id': 217,
#   'image': 'https://books.toscrape.com/media/cache/72/73/7273ff1bfe3b0a6aab7f54ddf9be7b44.jpg',
#   'price': 21.94,
#   'rating': 1,
#   'title': 'Can You Keep a Secret?'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 358,
#   'image': 'https://books.toscrape.com/media/cache/b5/6f/b56ff04effb66fe701a22abd4a7f1667.jpg',
#   'price': 21.95,
#   'rating': 2,
#   'title': 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon'},
#  {'availability': 'In stock',
#   'category': 'Romance',
#   'id': 179,
#   'image': 'https://books.toscrape.com/media/cache/cc/bd/ccbdae9e29b3594301528fa2c876ec29.jpg',
#   'price': 21.96,
#   'rating': 1,
#   'title': 'Fifty Shades Darker (Fifty Shades #2)'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 262,
#   'image': 'https://books.toscrape.com/media/cache/2d/7b/2d7b77d8b45b2f8e1bc0ce20aacddad0.jpg',
#   'price': 21.96,
#   'rating': 4,
#   'title': 'Hystopia: A Novel'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 339,
#   'image': 'https://books.toscrape.com/media/cache/fe/ea/feeafd2ad7b3077f8e74cbb1da9e3c7d.jpg',
#   'price': 22.0,
#   'rating': 4,
#   'title': 'In the Country We Love: My Family Divided'},
#  {'availability': 'In stock',
#   'category': 'Fantasy',
#   'id': 728,
#   'image': 'https://books.toscrape.com/media/cache/d7/f0/d7f00033bda3779b2fd017e32e7c800c.jpg',
#   'price': 22.06,
#   'rating': 4,
#   'title': 'Ash'},
#  {'availability': 'In stock',
#   'category': 'Childrens',
#   'id': 298,
#   'image': 'https://books.toscrape.com/media/cache/2b/38/2b380f77723c797c0389f978afa6db58.jpg',
#   'price': 22.08,
#   'rating': 2,
#   'title': 'Twenty Yawns'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 280,
#   'image': 'https://books.toscrape.com/media/cache/68/a6/68a6112c857e595c684f2a1a3287ba16.jpg',
#   'price': 22.1,
#   'rating': 1,
#   'title': 'The Art of Fielding'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 285,
#   'image': 'https://books.toscrape.com/media/cache/ef/b7/efb72b546fc7cab4ba1735b4b82c5851.jpg',
#   'price': 22.11,
#   'rating': 1,
#   'title': 'Big Little Lies'},
#  {'availability': 'In stock',
#   'category': 'Sequential Art',
#   'id': 86,
#   'image': 'https://books.toscrape.com/media/cache/90/6f/906f0168b0e155a7077625499b1737b5.jpg',
#   'price': 22.11,
#   'rating': 2,
#   'title': 'Giant Days, Vol. 2 (Giant Days #5-8)'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 672,
#   'image': 'https://books.toscrape.com/media/cache/9d/56/9d5631724c6496b2f012fa5d2f2b6abd.jpg',
#   'price': 22.13,
#   'rating': 4,
#   'title': 'The End of Faith: Religion, Terror, and the Future of Reason'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 636,
#   'image': 'https://books.toscrape.com/media/cache/f5/58/f55886d1bf600529a35e1bd932c78ca0.jpg',
#   'price': 22.13,
#   'rating': 4,
#   'title': 'Code Name Verity (Code Name Verity #1)'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 572,
#   'image': 'https://books.toscrape.com/media/cache/11/71/117145e4525b2e801e2cd1ba4dd70441.jpg',
#   'price': 22.14,
#   'rating': 2,
#   'title': 'The Girl Who Played with Fire (Millennium Trilogy #2)'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 528,
#   'image': 'https://books.toscrape.com/media/cache/0c/07/0c07b114195b45c156f7f1e23820c49a.jpg',
#   'price': 22.14,
#   'rating': 2,
#   'title': 'Wildlife of New York: A Five-Borough Coloring Book'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 477,
#   'image': 'https://books.toscrape.com/media/cache/d6/1b/d61b12ef0e69d49e2645537dd6a8472a.jpg',
#   'price': 22.16,
#   'rating': 2,
#   'title': 'Grumbles'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 417,
#   'image': 'https://books.toscrape.com/media/cache/74/c2/74c2893188f917409ba564d46f481f77.jpg',
#   'price': 22.2,
#   'rating': 1,
#   'title': 'Letter to a Christian Nation'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 663,
#   'image': 'https://books.toscrape.com/media/cache/f6/f2/f6f2094e8a318093fa53784df2bfeab8.jpg',
#   'price': 22.37,
#   'rating': 1,
#   'title': 'Find Her (Detective D.D. Warren #8)'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 454,
#   'image': 'https://books.toscrape.com/media/cache/ef/0b/ef0bed08de4e083dba5e20fdb98d9c36.jpg',
#   'price': 22.5,
#   'rating': 3,
#   'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana"},
#  {'availability': 'In stock',
#   'category': 'Childrens',
#   'id': 307,
#   'image': 'https://books.toscrape.com/media/cache/c0/bb/c0bb6e42743b9c1aaf9b754501100a5d.jpg',
#   'price': 22.54,
#   'rating': 1,
#   'title': 'Maybe Something Beautiful: How Art Transformed a Neighborhood'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 452,
#   'image': 'https://books.toscrape.com/media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg',
#   'price': 22.6,
#   'rating': 4,
#   'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics'},
#  {'availability': 'In stock',
#   'category': 'Young Adult',
#   'id': 744,
#   'image': 'https://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg',
#   'price': 22.65,
#   'rating': 1,
#   'title': 'The Requiem Red'},
#  {'availability': 'In stock',
#   'category': 'Childrens',
#   'id': 320,
#   'image': 'https://books.toscrape.com/media/cache/d6/cc/d6cc0c66e34dfc214b406208bbaf18e2.jpg',
#   'price': 22.85,
#   'rating': 3,
#   'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 279,
#   'image': 'https://books.toscrape.com/media/cache/cf/d5/cfd553eaa00f4d6091c459081cd98199.jpg',
#   'price': 22.96,
#   'rating': 2,
#   'title': 'The Da Vinci Code (Robert Langdon #2)'},
#  {'availability': 'In stock',
#   'category': 'Mystery',
#   'id': 34,
#   'image': 'https://books.toscrape.com/media/cache/3a/2c/3a2c46cd40a7ecbd7c40815d6390fb8a.jpg',
#   'price': 23.05,
#   'rating': 5,
#   'title': 'The Silkworm (Cormoran Strike #2)'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 331,
#   'image': 'https://books.toscrape.com/media/cache/9c/46/9c463c7631c82401160fd3b554b8f0e1.jpg',
#   'price': 23.11,
#   'rating': 5,
#   'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 469,
#   'image': 'https://books.toscrape.com/media/cache/81/58/81586cd0bf8743e1f5ed80b6a0e1fabe.jpg',
#   'price': 23.15,
#   'rating': 2,
#   'title': 'The Emerald Mystery'},
#  {'availability': 'In stock',
#   'category': 'Travel',
#   'id': 9,
#   'image': 'https://books.toscrape.com/media/cache/e0/4f/e04f8eda2a2fa947aec17640202d9ab0.jpg',
#   'price': 23.21,
#   'rating': 1,
#   'title': 'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 275,
#   'image': 'https://books.toscrape.com/media/cache/1d/8e/1d8eb8aaebd14464fc58a681091b8d45.jpg',
#   'price': 23.21,
#   'rating': 3,
#   'title': 'Three-Martini Lunch'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 550,
#   'image': 'https://books.toscrape.com/media/cache/58/e4/58e434a6a4eb267eac7aa529b0c2ec15.jpg',
#   'price': 23.32,
#   'rating': 1,
#   'title': 'Harry Potter and the Deathly Hallows (Harry Potter #7)'},
#  {'availability': 'In stock',
#   'category': 'Horror',
#   'id': 875,
#   'image': 'https://books.toscrape.com/media/cache/30/66/3066f8bcd2e2ed6b45084355ff084a61.jpg',
#   'price': 23.37,
#   'rating': 3,
#   'title': 'Red Dragon (Hannibal Lecter #1)'},
#  {'availability': 'In stock',
#   'category': 'Horror',
#   'id': 870,
#   'image': 'https://books.toscrape.com/media/cache/6d/10/6d10387a0175701d4ff456a0c7eee67b.jpg',
#   'price': 23.4,
#   'rating': 1,
#   'title': 'The Loney'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 575,
#   'image': 'https://books.toscrape.com/media/cache/84/07/84074b59293cc5bf4012ef0f60e90c4f.jpg',
#   'price': 23.43,
#   'rating': 2,
#   'title': 'The Autobiography of Malcolm X'},
#  {'availability': 'In stock',
#   'category': 'Childrens',
#   'id': 299,
#   'image': 'https://books.toscrape.com/media/cache/bb/e2/bbe26db72b8a32117bfe4981b7cc8147.jpg',
#   'price': 23.57,
#   'rating': 3,
#   'title': 'Rain Fish'},
#  {'availability': 'In stock',
#   'category': 'Food and Drink',
#   'id': 930,
#   'image': 'https://books.toscrape.com/media/cache/8e/09/8e09faaea71886048b27959e607e6c7b.jpg',
#   'price': 23.59,
#   'rating': 1,
#   'title': 'The Smitten Kitchen Cookbook'},
#  {'availability': 'In stock',
#   'category': 'Young Adult',
#   'id': 778,
#   'image': 'https://books.toscrape.com/media/cache/bc/c8/bcc8374e0c81ded1486b6225ca4fe78a.jpg',
#   'price': 23.63,
#   'rating': 4,
#   'title': 'Lola and the Boy Next Door (Anna and the French Kiss #2)'},
#  {'availability': 'In stock',
#   'category': 'Thriller',
#   'id': 957,
#   'image': 'https://books.toscrape.com/media/cache/5d/7e/5d7ecde8e81513eba8a64c9fe000744b.jpg',
#   'price': 23.82,
#   'rating': 5,
#   'title': 'The Elephant Tree'},
#  {'availability': 'In stock',
#   'category': 'Poetry',
#   'id': 815,
#   'image': 'https://books.toscrape.com/media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg',
#   'price': 23.88,
#   'rating': 1,
#   'title': 'Olio'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 625,
#   'image': 'https://books.toscrape.com/media/cache/f8/6d/f86d08178e3788563ac17be5aefd29f0.jpg',
#   'price': 23.89,
#   'rating': 4,
#   'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 591,
#   'image': 'https://books.toscrape.com/media/cache/51/bf/51bf575f9af355f4f9f98abe8986402a.jpg',
#   'price': 23.9,
#   'rating': 5,
#   'title': 'Dark Places'},
#  {'availability': 'In stock',
#   'category': 'Business',
#   'id': 942,
#   'image': 'https://books.toscrape.com/media/cache/19/aa/19aa1184a3565b1dae6092146018e109.jpg',
#   'price': 23.99,
#   'rating': 2,
#   'title': 'Shoe Dog: A Memoir by the Creator of NIKE'},
#  {'availability': 'In stock',
#   'category': 'Contemporary',
#   'id': 969,
#   'image': 'https://books.toscrape.com/media/cache/4d/18/4d1891e435c6692c864331c585e0d014.jpg',
#   'price': 24.04,
#   'rating': 1,
#   'title': 'We Are All Completely Beside Ourselves'},
#  {'availability': 'In stock',
#   'category': 'Romance',
#   'id': 180,
#   'image': 'https://books.toscrape.com/media/cache/28/99/28992d89f4abf54fba183fc8d074adf3.jpg',
#   'price': 24.12,
#   'rating': 1,
#   'title': 'The Wedding Dress'},
#  {'availability': 'In stock',
#   'category': 'Young Adult',
#   'id': 782,
#   'image': 'https://books.toscrape.com/media/cache/d1/fb/d1fbdddb0d4fb0c445a33c6d003d0990.jpg',
#   'price': 24.17,
#   'rating': 4,
#   'title': 'Harry Potter and the Prisoner of Azkaban (Harry Potter #3)'},
#  {'availability': 'In stock',
#   'category': 'Sports and Games',
#   'id': 621,
#   'image': 'https://books.toscrape.com/media/cache/c3/a9/c3a90a5baa833a37c29c4b03a444737c.jpg',
#   'price': 24.42,
#   'rating': 1,
#   'title': 'Sugar Rush (Offensive Line #2)'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 243,
#   'image': 'https://books.toscrape.com/media/cache/e0/79/e07906c1e507055da9a2260a74f58273.jpg',
#   'price': 24.48,
#   'rating': 3,
#   'title': 'My Mrs. Brown'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 674,
#   'image': 'https://books.toscrape.com/media/cache/70/f4/70f4dbf8110363f4e7ef32db0ce2a675.jpg',
#   'price': 24.55,
#   'rating': 1,
#   'title': 'The Catcher in the Rye'},
#  {'availability': 'In stock',
#   'category': 'Religion',
#   'id': 324,
#   'image': 'https://books.toscrape.com/media/cache/83/db/83dbf86eb0fed1d99de2148eac4eb064.jpg',
#   'price': 24.57,
#   'rating': 3,
#   'title': 'The Book of Mormon'},
#  {'availability': 'In stock',
#   'category': 'Nonfiction',
#   'id': 375,
#   'image': 'https://books.toscrape.com/media/cache/40/b2/40b246cf12df5345dc0371c040fddb4b.jpg',
#   'price': 24.57,
#   'rating': 2,
#   'title': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 579,
#   'image': 'https://books.toscrape.com/media/cache/d9/ea/d9ea34aea25469189bca07af6a18790a.jpg',
#   'price': 24.61,
#   'rating': 2,
#   'title': 'Orange Is the New Black'},
#  {'availability': 'In stock',
#   'category': 'History',
#   'id': 890,
#   'image': 'https://books.toscrape.com/media/cache/3d/60/3d6003fc37b842a07c2dbe28e47448e1.jpg',
#   'price': 24.7,
#   'rating': 3,
#   'title': 'Zealot: The Life and Times of Jesus of Nazareth'},
#  {'availability': 'In stock',
#   'category': 'Fantasy',
#   'id': 723,
#   'image': 'https://books.toscrape.com/media/cache/7b/96/7b96f6e11b388ee800c7fd17fe479444.jpg',
#   'price': 24.72,
#   'rating': 2,
#   'title': 'Soldier (Talon #3)'},
#  {'availability': 'In stock',
#   'category': 'Mystery',
#   'id': 38,
#   'image': 'https://books.toscrape.com/media/cache/9e/ff/9eff8b66d583e8f0ba58a0bc86de40f2.jpg',
#   'price': 24.72,
#   'rating': 2,
#   'title': 'Career of Evil (Cormoran Strike #3)'},
#  {'availability': 'In stock',
#   'category': 'Fiction',
#   'id': 268,
#   'image': 'https://books.toscrape.com/media/cache/50/a9/50a901fb008c0b8965c8d4da2dff5470.jpg',
#   'price': 24.73,
#   'rating': 3,
#   'title': 'The Little Paris Bookshop'},
#  {'availability': 'In stock',
#   'category': 'Mystery',
#   'id': 32,
#   'image': 'https://books.toscrape.com/media/cache/32/94/3294e5eaf73a37958583483fc9a90f04.jpg',
#   'price': 24.8,
#   'rating': 4,
#   'title': 'The Mysterious Affair at Styles (Hercule Poirot #1)'},
#  {'availability': 'In stock',
#   'category': 'Add a comment',
#   'id': 690,
#   'image': 'https://books.toscrape.com/media/cache/33/73/3373a168b588e3fb19c558a21da71ac9.jpg',
#   'price': 24.89,
#   'rating': 3,
#   'title': 'Lord of the Flies'},
#  {'availability': 'In stock',
#   'category': 'Food and Drink',
#   'id': 928,
#   'image': 'https://books.toscrape.com/media/cache/5d/02/5d029bff299cdb777e06f35800faa628.jpg',
#   'price': 24.91,
#   'rating': 5,
#   'title': 'Mexican Today: New and Rediscovered Recipes for Contemporary Kitchens'},
#  {'availability': 'In stock',
#   'category': 'Default',
#   'id': 599,
#   'image': 'https://books.toscrape.com/media/cache/66/f9/66f9edebe41032584e08dcf2fc27b8b4.jpg',
#   'price': 24.96,
#   'rating': 1,
#   'title': 'Paradise Lost (Paradise #1)'}]

# %% [markdown]
# ### Search

# %%
# colocar no dict os termos de busca (nenhum deles é obrigatório)
params = {'title':'life', 'category':''}

search = f"{url}/api/v1/books/search"
resp = requests.get(search, params = params).json()
# print(resp)

# %% [markdown]
# ### Livros pelo ID

# %%
id = 32

livro_id = f"{url}/api/v1/books/{id}"
resp = requests.get(livro_id).json()
print(resp)
# Out:
# {'availability': 'In stock', 'category': 'Mystery', 'id': 32, 'image': 'https://books.toscrape.com/media/cache/32/94/3294e5eaf73a37958583483fc9a90f04.jpg', 'price': 24.8, 'rating': 4, 'title': 'The Mysterious Affair at Styles (Hercule Poirot #1)'}

# %% [markdown]
# ### Top-rated

# %%
top_rated = f"{url}/api/v1/books/top-rated"
resp = requests.get(top_rated).json()
# print(resp)

# %% [markdown]
# ### Categories

# %%
categories = f"{url}/api/v1/categories"
resp = requests.get(categories).json()
print(resp)

# %% [markdown]
# ## 3. Stats

# %%
overview = f"{url}/api/v1/stats/overview"
resp = requests.get(overview).json()
resp

# %%
categories = f"{url}/api/v1/stats/categories"
resp = requests.get(categories).json()
resp
