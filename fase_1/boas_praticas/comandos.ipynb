# %%
# no terminal:

py -0 # mostra todas as versões do python instaladas


uv python install [versão do python]
uv init # inicia novo projeto
uv venv # cria um ambiente virtual
# vai ter um arquivo .python-version que tem a versão do python instalada no projeto

touch README.md # cria um arquivo markdown README

# %% [markdown]
# ## Anotações
#
# - no script main.py, colocar a principal função no início do script
