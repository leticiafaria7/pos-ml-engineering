# %% [markdown]
# ## Imports

# %%
import requests
import warnings
warnings.filterwarnings('ignore')

url = 'https://books-catalog-api.onrender.com'

# %% [markdown]
# ## 1. Registro e login de usuário

# %%
# alterar as chaves para os username e password desejados
username = 'teste_prod3'
password = 'senha'

payload = {'username':username, 'password':password}

resp = requests.post(f"{url}/api/v1/auth/register", json = payload)
print(resp.json())
# Out:
# {'message': 'Usuário criado com sucesso'}

# %%
# colocar username e senha registrados
payload = {'username':username, 'password':password}
resp = requests.post(f"{url}/api/v1/auth/login", json = payload)

# armazenar o token de acesso na variável access_token
access_token = resp.json()['access_token'] 
print(access_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..jmtD5VbinXh7Y70BI6MW8pyPTcd7w_riVYjgD2oAAQo

# %% [markdown]
# ## 2. Informações dos livros

# %% [markdown]
# ### Lista de livros

# %%
header = {'Authorization': f"Bearer {access_token}"}
endpoint_livros = f"{url}/api/v1/books"

# armazenar a lista de livros na variável lista_livros
lista_livros = requests.get(endpoint_livros, headers = header).json()

# %%
# lista_livros

# %% [markdown]
# ### Faixa de preço

# %%
# colocar no dict os termos de busca (nenhum deles é obrigatório)
params = {'min':20, 'max':25}

price_range = f"{url}/api/v1/books/price-range"
resp = requests.get(price_range, params = params).json()
# resp

# %% [markdown]
# ### Search

# %%
# colocar no dict os termos de busca (nenhum deles é obrigatório)
params = {'title':'dog', 'category':''}

search = f"{url}/api/v1/books/search"
resp = requests.get(search, params = params).json()
print(resp)
# Out:
# [{'availability': 'In stock', 'category': 'Religion', 'id': 321, 'image': 'https://books.toscrape.com/media/cache/95/30/953013d044aa313cc162dec414f3969a.jpg', 'price': 37.97, 'rating': 2, 'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master"}, {'availability': 'In stock', 'category': 'Default', 'id': 590, 'image': 'https://books.toscrape.com/media/cache/df/95/df9520adbabbb17f22fcb3f49c69640f.jpg', 'price': 17.81, 'rating': 1, 'title': 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants'}, {'availability': 'In stock', 'category': 'Business', 'id': 942, 'image': 'https://books.toscrape.com/media/cache/19/aa/19aa1184a3565b1dae6092146018e109.jpg', 'price': 23.99, 'rating': 2, 'title': 'Shoe Dog: A Memoir by the Creator of NIKE'}]

# %% [markdown]
# ### Livros pelo ID

# %%
id = 32

livro_id = f"{url}/api/v1/books/{id}"
resp = requests.get(livro_id).json()
print(resp)
# Out:
# [{'availability': 'In stock', 'category': 'Mystery', 'id': 32, 'image': 'https://books.toscrape.com/media/cache/32/94/3294e5eaf73a37958583483fc9a90f04.jpg', 'price': 24.8, 'rating': 4, 'title': 'The Mysterious Affair at Styles (Hercule Poirot #1)'}]

# %% [markdown]
# ### Top-rated

# %%
top_rated = f"{url}/api/v1/books/top-rated"
resp = requests.get(top_rated).json()
# print(resp)

# %% [markdown]
# ### Categories

# %%
categories = f"{url}/api/v1/categories"
resp = requests.get(categories).json()
print(resp)
# Out:
# {'categories': ['Travel', 'Mystery', 'Historical Fiction', 'Sequential Art', 'Classics', 'Philosophy', 'Romance', 'Womens Fiction', 'Fiction', 'Childrens', 'Religion', 'Nonfiction', 'Music', 'Default', 'Science Fiction', 'Sports and Games', 'Add a comment', 'Fantasy', 'New Adult', 'Young Adult', 'Science', 'Poetry', 'Paranormal', 'Art', 'Psychology', 'Autobiography', 'Parenting', 'Adult Fiction', 'Humor', 'Horror', 'History', 'Food and Drink', 'Christian Fiction', 'Business', 'Biography', 'Thriller', 'Contemporary', 'Spirituality', 'Academic', 'Self Help', 'Historical', 'Christian', 'Suspense', 'Short Stories', 'Novels', 'Health', 'Politics', 'Cultural', 'Erotica', 'Crime']}

# %% [markdown]
# ## 3. Stats

# %%
overview = f"{url}/api/v1/stats/overview"
resp = requests.get(overview).json()
resp
# Out:
# {'mean_price': 35.07,
#  'ratings_distribution': {'1': 226, '2': 196, '3': 203, '4': 179, '5': 195},
#  'total_books': 999}

# %%
categories = f"{url}/api/v1/stats/categories"
resp = requests.get(categories).json()
resp
# Out:
# {'Academic': {'n_books': 1,
#   'price_max': 13.12,
#   'price_mean': 13.12,
#   'price_min': 13.12,
#   'rating_mean': 2.0},
#  'Add a comment': {'n_books': 67,
#   'price_max': 59.15,
#   'price_mean': 35.8,
#   'price_min': 10.02,
#   'rating_mean': 2.76},
#  'Adult Fiction': {'n_books': 1,
#   'price_max': 15.36,
#   'price_mean': 15.36,
#   'price_min': 15.36,
#   'rating_mean': 5.0},
#  'Art': {'n_books': 8,
#   'price_max': 49.05,
#   'price_mean': 38.52,
#   'price_min': 10.29,
#   'rating_mean': 3.62},
#  'Autobiography': {'n_books': 9,
#   'price_max': 59.04,
#   'price_mean': 37.05,
#   'price_min': 10.93,
#   'rating_mean': 3.0},
#  'Biography': {'n_books': 5,
#   'price_max': 48.19,
#   'price_mean': 33.66,
#   'price_min': 16.85,
#   'rating_mean': 2.2},
#  'Business': {'n_books': 12,
#   'price_max': 51.74,
#   'price_mean': 32.46,
#   'price_min': 12.61,
#   'rating_mean': 2.92},
#  'Childrens': {'n_books': 29,
#   'price_max': 58.08,
#   'price_mean': 32.64,
#   'price_min': 10.62,
#   'rating_mean': 2.62},
#  'Christian': {'n_books': 3,
#   'price_max': 54.0,
#   'price_mean': 42.5,
#   'price_min': 25.77,
#   'rating_mean': 2.67},
#  'Christian Fiction': {'n_books': 6,
#   'price_max': 49.97,
#   'price_mean': 34.38,
#   'price_min': 17.97,
#   'rating_mean': 4.17},
#  'Classics': {'n_books': 19,
#   'price_max': 58.63,
#   'price_mean': 36.55,
#   'price_min': 14.82,
#   'rating_mean': 2.47},
#  'Contemporary': {'n_books': 3,
#   'price_max': 52.79,
#   'price_mean': 36.2,
#   'price_min': 24.04,
#   'rating_mean': 2.33},
#  'Crime': {'n_books': 1,
#   'price_max': 10.97,
#   'price_mean': 10.97,
#   'price_min': 10.97,
#   'rating_mean': 1.0},
#  'Cultural': {'n_books': 1,
#   'price_max': 36.58,
#   'price_mean': 36.58,
#   'price_min': 36.58,
#   'rating_mean': 1.0},
#  'Default': {'n_books': 152,
#   'price_max': 58.87,
#   'price_mean': 34.39,
#   'price_min': 10.23,
#   'rating_mean': 2.84},
#  'Erotica': {'n_books': 1,
#   'price_max': 19.19,
#   'price_mean': 19.19,
#   'price_min': 19.19,
#   'rating_mean': 5.0},
#  'Fantasy': {'n_books': 47,
#   'price_max': 58.75,
#   'price_mean': 39.75,
#   'price_min': 12.16,
#   'rating_mean': 3.04},
#  'Fiction': {'n_books': 65,
#   'price_max': 59.98,
#   'price_mean': 36.07,
#   'price_min': 10.6,
#   'rating_mean': 3.18},
#  'Food and Drink': {'n_books': 30,
#   'price_max': 59.92,
#   'price_mean': 31.41,
#   'price_min': 11.05,
#   'rating_mean': 2.9},
#  'Health': {'n_books': 4,
#   'price_max': 54.07,
#   'price_mean': 51.45,
#   'price_min': 49.05,
#   'rating_mean': 3.75},
#  'Historical': {'n_books': 2,
#   'price_max': 29.87,
#   'price_mean': 22.83,
#   'price_min': 15.79,
#   'rating_mean': 3.0},
#  'Historical Fiction': {'n_books': 26,
#   'price_max': 55.55,
#   'price_mean': 33.64,
#   'price_min': 16.62,
#   'rating_mean': 3.23},
#  'History': {'n_books': 18,
#   'price_max': 59.64,
#   'price_mean': 37.29,
#   'price_min': 11.45,
#   'rating_mean': 2.94},
#  'Horror': {'n_books': 17,
#   'price_max': 57.86,
#   'price_mean': 35.95,
#   'price_min': 10.56,
#   'rating_mean': 2.71},
#  'Humor': {'n_books': 10,
#   'price_max': 55.5,
#   'price_mean': 33.5,
#   'price_min': 11.83,
#   'rating_mean': 3.4},
#  'Music': {'n_books': 13,
#   'price_max': 57.25,
#   'price_mean': 35.64,
#   'price_min': 12.36,
#   'rating_mean': 3.15},
#  'Mystery': {'n_books': 32,
#   'price_max': 59.48,
#   'price_mean': 31.72,
#   'price_min': 10.69,
#   'rating_mean': 2.94},
#  'New Adult': {'n_books': 6,
#   'price_max': 58.35,
#   'price_mean': 46.38,
#   'price_min': 36.29,
#   'rating_mean': 3.17},
#  'Nonfiction': {'n_books': 110,
#   'price_max': 59.9,
#   'price_mean': 34.26,
#   'price_min': 11.68,
#   'rating_mean': 2.88},
#  'Novels': {'n_books': 1,
#   'price_max': 54.81,
#   'price_mean': 54.81,
#   'price_min': 54.81,
#   'rating_mean': 5.0},
#  'Paranormal': {'n_books': 1,
#   'price_max': 15.4,
#   'price_mean': 15.4,
#   'price_min': 15.4,
#   'rating_mean': 1.0},
#  'Parenting': {'n_books': 1,
#   'price_max': 37.35,
#   'price_mean': 37.35,
#   'price_min': 37.35,
#   'rating_mean': 2.0},
#  'Philosophy': {'n_books': 11,
#   'price_max': 58.11,
#   'price_mean': 33.56,
#   'price_min': 15.94,
#   'rating_mean': 2.36},
#  'Poetry': {'n_books': 19,
#   'price_max': 57.31,
#   'price_mean': 35.97,
#   'price_min': 14.19,
#   'rating_mean': 3.53},
#  'Politics': {'n_books': 3,
#   'price_max': 56.86,
#   'price_mean': 53.61,
#   'price_min': 51.33,
#   'rating_mean': 2.33},
#  'Psychology': {'n_books': 7,
#   'price_max': 59.95,
#   'price_mean': 34.22,
#   'price_min': 10.4,
#   'rating_mean': 1.71},
#  'Religion': {'n_books': 7,
#   'price_max': 57.49,
#   'price_mean': 32.57,
#   'price_min': 21.87,
#   'rating_mean': 3.14},
#  'Romance': {'n_books': 35,
#   'price_max': 59.99,
#   'price_mean': 33.93,
#   'price_min': 11.1,
#   'rating_mean': 2.63},
#  'Science': {'n_books': 14,
#   'price_max': 57.36,
#   'price_mean': 33.09,
#   'price_min': 10.01,
#   'rating_mean': 2.93},
#  'Science Fiction': {'n_books': 16,
#   'price_max': 54.86,
#   'price_mean': 33.8,
#   'price_min': 10.65,
#   'rating_mean': 2.25},
#  'Self Help': {'n_books': 5,
#   'price_max': 52.15,
#   'price_mean': 40.62,
#   'price_min': 12.08,
#   'rating_mean': 2.6},
#  'Sequential Art': {'n_books': 75,
#   'price_max': 57.62,
#   'price_mean': 34.57,
#   'price_min': 10.16,
#   'rating_mean': 2.97},
#  'Short Stories': {'n_books': 1,
#   'price_max': 35.88,
#   'price_mean': 35.88,
#   'price_min': 35.88,
#   'rating_mean': 1.0},
#  'Spirituality': {'n_books': 6,
#   'price_max': 55.65,
#   'price_mean': 35.1,
#   'price_min': 17.66,
#   'rating_mean': 3.33},
#  'Sports and Games': {'n_books': 5,
#   'price_max': 51.22,
#   'price_mean': 41.17,
#   'price_min': 24.42,
#   'rating_mean': 3.0},
#  'Suspense': {'n_books': 1,
#   'price_max': 58.33,
#   'price_mean': 58.33,
#   'price_min': 58.33,
#   'rating_mean': 3.0},
#  'Thriller': {'n_books': 11,
#   'price_max': 59.71,
#   'price_mean': 31.43,
#   'price_min': 12.84,
#   'rating_mean': 2.73},
#  'Travel': {'n_books': 11,
#   'price_max': 56.88,
#   'price_mean': 39.79,
#   'price_min': 23.21,
#   'rating_mean': 2.73},
#  'Womens Fiction': {'n_books': 17,
#   'price_max': 57.36,
#   'price_mean': 36.79,
#   'price_min': 13.73,
#   'rating_mean': 3.12},
#  'Young Adult': {'n_books': 54,
#   'price_max': 58.14,
#   'price_mean': 35.45,
#   'price_min': 10.0,
#   'rating_mean': 3.3}}
